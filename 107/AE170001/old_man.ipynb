# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\USER\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\USER\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\USER\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\USER\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data = pd.read_csv('data107old.csv')

# %% [markdown]
# # 先查看資料型態

# %%
data.head()
# Out:
#    v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  v43  \
# 0  12  640  40   2   2     99     99     99   1   2  ...    1    9    2    1
# 1  13  614  25   5   5      7     99     99   4   2  ...    2    2    8    8
# 2   4  262  41   2   1     99     99     99   1   1  ...    1    9    2    1
# 3  17  906  44   1   3      7     99     99   3   2  ...    1    9    1    1
# 4  10  510  27   5   1     99     99     99   1   2  ...    1    9    2    8
#
#    v44  v45  v46  v47    wei1    wei2
# 0    8    3    1    2  0.7768  0.8770
# 1    1    3    1    1  0.6791  0.5974
# 2    2    4    1    1  0.9525  0.6488
# 3    1    5    1    1  1.0841  1.4201
# 4    4    1    2    2  0.7935  1.4707
#
# [5 rows x 100 columns]

# %% [markdown]
# # 觀察老人覺得自己快樂人數

# %%
data_happy = data[(data['v6'] > 3) & (data['v6'] <8) ]

# %%
data_happy
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 1     13  614  25   5   5      7     99     99   4   2  ...    2    2    8
# 19    17  904  98   1   4     96     99     99   4   2  ...    1    9    2
# 22    10  510  44   1   2     99     99     99   4   2  ...    1    9    1
# 24     4  261  31   4   4      7      6     99   4   2  ...    1    9    8
# 27    12  638  98   5   4      5      2     99   4   2  ...    2    2    2
# 31    12  654  98   4   5      5     99     99   5   2  ...    2    2    2
# 34    17  928  98   5   2     99     99     99   4   2  ...    1    9    1
# 35    17  900  47   1   4     96     99     99   4   2  ...    2    1    2
# 46    13  998  98   5   4      7     99     99   4   2  ...    1    9    8
# 52    18  880  16   6   4      5     99     99   4   2  ...    2    2    1
# 53    17  904  27   5   4      5     99     99   5   2  ...    2    2    2
# ...

# %%
data_unhappy = data[data['v6']<4]

# %%
data_unhappy
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 0     12  640  40   2   2     99     99     99   1   2  ...    1    9    2
# 2      4  262  41   2   1     99     99     99   1   1  ...    1    9    2
# 3     17  906  44   1   3      7     99     99   3   2  ...    1    9    1
# 4     10  510  27   5   1     99     99     99   1   2  ...    1    9    2
# 5     18  885  98   6   4      8     99     99   3   2  ...    2    1    2
# 6     17  926  45   1   1     99     99     99   1   1  ...    1    9    1
# 7      4  265  42   2   1     99     99     99   1   1  ...    2    1    1
# 8     10  515  38   2   2     99     99     99   2   2  ...    1    9    1
# 9     12  632  42   2   4      1     99     99   3   2  ...    1    9    2
# 10    10  523  41   2   2     99     99     99   2   1  ...    2    2    1
# 11    13  613  43   1   5      5      6     99   2   2  ...    2    1    2
# ...

# %% [markdown]
# # 查看老人健康和不健康比例

# %%
data_health = data[(data['v5'] >= 3) & (data['v5'] <8) ]

# %%
data_health
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 1     13  614  25   5   5      7     99     99   4   2  ...    2    2    8
# 3     17  906  44   1   3      7     99     99   3   2  ...    1    9    1
# 5     18  885  98   6   4      8     99     99   3   2  ...    2    1    2
# 9     12  632  42   2   4      1     99     99   3   2  ...    1    9    2
# 11    13  613  43   1   5      5      6     99   2   2  ...    2    1    2
# 14    13  608  37   3   3     96     99     99   3   2  ...    1    9    2
# 16     4  260  98   3   3      7     99     99   2   2  ...    1    9    1
# 17    17  900  30   4   4     96      7     99   1   2  ...    1    9    1
# 19    17  904  98   1   4     96     99     99   4   2  ...    1    9    2
# 24     4  261  31   4   4      7      6     99   4   2  ...    1    9    8
# 25    12  640  46   1   3     98     99     99   1   1  ...    1    9    1
# ...

# %%
data_unhealth = data[data['v5'] < 3]

# %%
data_unhealth
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 0     12  640  40   2   2     99     99     99   1   2  ...    1    9    2
# 2      4  262  41   2   1     99     99     99   1   1  ...    1    9    2
# 4     10  510  27   5   1     99     99     99   1   2  ...    1    9    2
# 6     17  926  45   1   1     99     99     99   1   1  ...    1    9    1
# 7      4  265  42   2   1     99     99     99   1   1  ...    2    1    1
# 8     10  515  38   2   2     99     99     99   2   2  ...    1    9    1
# 10    10  523  41   2   2     99     99     99   2   1  ...    2    2    1
# 12    10  508  33   3   2     99     99     99   8   2  ...    1    9    1
# 13     4  263  40   2   1     99     99     99   1   1  ...    1    9    2
# 15    12  636  35   3   2     99     99     99   1   2  ...    1    9    1
# 18    12  637  31   4   2     99     99     99   2   2  ...    1    9    8
# ...

# %% [markdown]
# # 查看使用網路比例在快樂和不快樂之中

# %%
data_int = data[data['v18'] ==1 ]
data_ununt = data[data['v18'] ==2 ]

# %%
data_int
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 6     17  926  45   1   1     99     99     99   1   1  ...    1    9    1
# 7      4  265  42   2   1     99     99     99   1   1  ...    2    1    1
# 10    10  523  41   2   2     99     99     99   2   1  ...    2    2    1
# 12    10  508  33   3   2     99     99     99   8   2  ...    1    9    1
# 13     4  263  40   2   1     99     99     99   1   1  ...    1    9    2
# 16     4  260  98   3   3      7     99     99   2   2  ...    1    9    1
# 17    17  900  30   4   4     96      7     99   1   2  ...    1    9    1
# 19    17  904  98   1   4     96     99     99   4   2  ...    1    9    2
# 21    10  510  98   1   8     99     99     99   8   1  ...    2    2    1
# 22    10  510  44   1   2     99     99     99   4   2  ...    1    9    1
# 26    17  912  40   2   2     99     99     99   2   2  ...    1    9    1
# ...

# %%
data_ununt
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 40     4  265  40   2   2     99     99     99   2   1  ...    2    2    1
# 44    17  905  25   5   2     99     99     99   1   2  ...    1    9    2
# 49    17  941  38   2   2     99     99     99   2   1  ...    1    9    1
# 54     4  262  98   1   2     99     99     99   1   1  ...    1    9    1
# 70    18  881  43   1   3      7     99     99   2   2  ...    1    9    1
# 72    18  880  45   1   4      7     99     99   4   2  ...    1    9    1
# 78    17  906  41   2   2     99     99     99   2   2  ...    1    9    1
# 95    17  920  40   2   4      7      1     99   2   1  ...    1    9    1
# 130   13  613  45   1   1     99     99     99   1   1  ...    1    9    1
# 150   10  516  43   1   1     99     99     99   1   2  ...    1    9    1
# 168   18  880  37   3   2     99     99     99   2   2  ...    1    9    1
# ...

# %% [markdown]
# # 查看交集 觀察是否快樂和有無上網有關

# %%
data_happy_int = data_happy[(data_happy['v18']) ==1 ]

# %%
data_happy_int
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 19    17  904  98   1   4     96     99     99   4   2  ...    1    9    2
# 22    10  510  44   1   2     99     99     99   4   2  ...    1    9    1
# 64    10  500  44   1   2     99     99     99   4   2  ...    1    9    1
# 79    18  880  34   3   4      5      7     99   4   2  ...    2    2    1
# 91     4  265  47   1   3      1     99     99   4   2  ...    1    9    1
# 125   13  603  46   1   5      5     99     99   5   1  ...    2    2    1
# 149   10  514  18   6   5      7     99     99   4   2  ...    2    2    2
# 239   10  503  43   1   5      5      7     99   4   1  ...    2    1    2
# 255    4  269  39   2   3      7     99     99   4   1  ...    2    1    2
# 258    4  260  36   3   4     96     99     99   4   2  ...    2    2    1
# 285    4  260  98   1   3     95     99     99   4   1  ...    1    9    1
# ...

# %%
data_happy_nint = data_happy[(data_happy['v18']) ==2 ]

# %%
data_happy_nint
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 72    18  880  45   1   4      7     99     99   4   2  ...    1    9    1
# 186   12  646  43   1   2     99     99     99   5   1  ...    2    1    2
# 281   17  923  47   1   5      7      1      5   5   2  ...    2    2    1
# 306   18  884  45   1   2     99     99     99   4   2  ...    2    2    2
# 354   17  909  40   2   2     99     99     99   4   2  ...    1    9    1
# 449   13  604  43   1   2     99     99     99   4   2  ...    2    2    2
# 671   10  500  44   1   3      7     99     99   4   2  ...    1    9    2
# 848   18  885  33   3   4     96      5     99   4   2  ...    1    9    1
# 884   12  652  35   3   5      7     99     99   4   2  ...    2    2    2
# 1078  13  612  33   3   4      7     99     99   4   2  ...    1    9    8
# 1083  17  912  29   4   5      1      5      4   5   2  ...    2    2    1
# ...

# %%
data_unhappy_int = data_unhappy[data_unhappy['v18'] ==1]

# %%
data_unhappy_int
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 6     17  926  45   1   1     99     99     99   1   1  ...    1    9    1
# 7      4  265  42   2   1     99     99     99   1   1  ...    2    1    1
# 10    10  523  41   2   2     99     99     99   2   1  ...    2    2    1
# 13     4  263  40   2   1     99     99     99   1   1  ...    1    9    2
# 16     4  260  98   3   3      7     99     99   2   2  ...    1    9    1
# 17    17  900  30   4   4     96      7     99   1   2  ...    1    9    1
# 26    17  912  40   2   2     99     99     99   2   2  ...    1    9    1
# 32    12  638  40   2   1     99     99     99   1   1  ...    1    9    2
# 36    12  646  47   1   2     99     99     99   1   1  ...    1    9    1
# 41    12  640  45   1   2     99     99     99   2   2  ...    1    9    2
# 48    17  920  31   4   2     99     99     99   2   2  ...    2    2    1
# ...

# %%
data_unhappy_nint = data_unhappy[data_unhappy['v18'] ==2]

# %%
data_unhappy_nint
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 40     4  265  40   2   2     99     99     99   2   1  ...    2    2    1
# 44    17  905  25   5   2     99     99     99   1   2  ...    1    9    2
# 49    17  941  38   2   2     99     99     99   2   1  ...    1    9    1
# 54     4  262  98   1   2     99     99     99   1   1  ...    1    9    1
# 70    18  881  43   1   3      7     99     99   2   2  ...    1    9    1
# 78    17  906  41   2   2     99     99     99   2   2  ...    1    9    1
# 95    17  920  40   2   4      7      1     99   2   1  ...    1    9    1
# 130   13  613  45   1   1     99     99     99   1   1  ...    1    9    1
# 150   10  516  43   1   1     99     99     99   1   2  ...    1    9    1
# 168   18  880  37   3   2     99     99     99   2   2  ...    1    9    1
# 194   13  625  42   2   3     96     99     99   1   2  ...    1    9    2
# ...

# %%
544/628
# Out:
# 0.8662420382165605

# %%
16.7 /0.65
# Out:
# 25.69230769230769

# %%
((data_happy_int['v20_1'] == 9) | (data_happy_int['v20_1'] == 6 )).sum()
# Out:
# 34

# %% [markdown]
# # 上網和健康

# %%
data_health_int = data_health[data_health['v18']!=2]

# %%
data_health_int
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 1     13  614  25   5   5      7     99     99   4   2  ...    2    2    8
# 3     17  906  44   1   3      7     99     99   3   2  ...    1    9    1
# 5     18  885  98   6   4      8     99     99   3   2  ...    2    1    2
# 9     12  632  42   2   4      1     99     99   3   2  ...    1    9    2
# 11    13  613  43   1   5      5      6     99   2   2  ...    2    1    2
# 14    13  608  37   3   3     96     99     99   3   2  ...    1    9    2
# 16     4  260  98   3   3      7     99     99   2   2  ...    1    9    1
# 17    17  900  30   4   4     96      7     99   1   2  ...    1    9    1
# 19    17  904  98   1   4     96     99     99   4   2  ...    1    9    2
# 24     4  261  31   4   4      7      6     99   4   2  ...    1    9    8
# 25    12  640  46   1   3     98     99     99   1   1  ...    1    9    1
# ...

# %%
data_unhealth_int = data_unhealth[data_unhealth['v18'] ==1]

# %%
data_unhealth_int
# Out:
#       v1   v2  v3  v4  v5  v5a_1  v5a_2  v5a_3  v6  v7  ...  v40  v41  v42  \
# 6     17  926  45   1   1     99     99     99   1   1  ...    1    9    1
# 7      4  265  42   2   1     99     99     99   1   1  ...    2    1    1
# 10    10  523  41   2   2     99     99     99   2   1  ...    2    2    1
# 12    10  508  33   3   2     99     99     99   8   2  ...    1    9    1
# 13     4  263  40   2   1     99     99     99   1   1  ...    1    9    2
# 22    10  510  44   1   2     99     99     99   4   2  ...    1    9    1
# 26    17  912  40   2   2     99     99     99   2   2  ...    1    9    1
# 32    12  638  40   2   1     99     99     99   1   1  ...    1    9    2
# 36    12  646  47   1   2     99     99     99   1   1  ...    1    9    1
# 41    12  640  45   1   2     99     99     99   2   2  ...    1    9    2
# 48    17  920  31   4   2     99     99     99   2   2  ...    2    2    1
# ...
